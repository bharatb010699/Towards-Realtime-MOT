# %% [markdown]
# <a href="https://colab.research.google.com/github/bharatb010699/Towards-Realtime-MOT/blob/master/MOT_Code_Rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/bharatb010699/Towards-Realtime-MOT.git"
# Out:
# Cloning into 'Towards-Realtime-MOT'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 404 (delta 8), reused 8 (delta 3), pack-reused 386
# Receiving objects: 100% (404/404), 21.41 MiB | 8.63 MiB/s, done.
# Resolving deltas: 100% (240/240), done.

# %%
# !pip install torch

# %%
# !pip install opencv-contrib-python

# %%
# !pip install motmetrics
# Out:
# ...
#      |████████████████████████████████| 153kB 2.7MB/s
# ...
#      |████████████████████████████████| 51kB 4.6MB/s
# ...
#      |████████████████████████████████| 81kB 5.6MB/s
# ...
#      |████████████████████████████████| 51kB 5.0MB/s
# ...
#      |████████████████████████████████| 92kB 5.5MB/s
# ...
#      |████████████████████████████████| 71kB 5.5MB/s
# ...
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-cp36-none-any.whl size=18684 sha256=f4d346a19221de3451f7bcb849aa1da8248713cc1f1ea8006fcd0001703d4816
#   Stored in directory: /root/.cache/pip/wheels/01/7e/a9/b982d0fea22b7e4ae5619de949570cde5ad55420cec16e86a5
# Successfully built py-cpuinfo
# ...

# %%
# !pip install cython_bbox
# Out:
# ...
#      |████████████████████████████████| 51kB 1.5MB/s
# ...
#   Created wheel for cython-bbox: filename=cython_bbox-0.1.3-cp36-cp36m-linux_x86_64.whl size=57164 sha256=21e662d5151099e5bbf3bed76e0e4b029cb7e344f83c15c36d0b065eba90aece
#   Stored in directory: /root/.cache/pip/wheels/2b/31/b5/9246d5988e79ef89dc28b894835d2f305e23c1e5f4f80278ee
# Successfully built cython-bbox
# ...

# %%
# !pip install --upgrade pytest
# Out:
# Requirement already up-to-date: pytest in /usr/local/lib/python3.6/dist-packages (5.4.2)
# ...

# %%
# !pip install folium==0.2.1
# Out:
# ...
#      |████████████████████████████████| 71kB 2.0MB/s
# ...
#   Created wheel for folium: filename=folium-0.2.1-cp36-none-any.whl size=79979 sha256=c96d376bca76a4087a6791c802fc93333da59fb79c43452f2f091d43d7fc6fb2
#   Stored in directory: /root/.cache/pip/wheels/b8/09/f0/52d2ef419c2aaf4fb149f92a33e0008bdce7ae816f0dd8f0c5
# Successfully built folium
# ...
#   Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# ...

# %%
# !pip install ffmpeg-python

# %%
# !pip install lap
# Out:
# ...
#      |████████████████████████████████| 1.5MB 2.7MB/s
# ...
#   Created wheel for lap: filename=lap-0.4.0-cp36-cp36m-linux_x86_64.whl size=1589034 sha256=ae8a48465c9228c850287108ff83e853eb00a38db30e2d34ce671bb168af597a
#   Stored in directory: /root/.cache/pip/wheels/da/3e/af/eddcd6ffaa27df8d0ddac573758f8953c4e57c64c4c8c8b7d0
# Successfully built lap
# ...

# %%
# !pip install googledrivedownloader

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd
gdd.download_file_from_google_drive(file_id='1254q3ruzBzgn4LUejDVsCtT05SIEieQg', dest_path='./mot16.zip',)
gdd.download_file_from_google_drive(file_id='1nlnuYfGNuHWZztQHXwVZSL_FvfE551pA', dest_path='./jde_1088x608_uncertainty.pt',)
gdd.download_file_from_google_drive(file_id='1UKgkYrsV-59kYaHgWeJ70p5Mij3QWuFr', dest_path='./jde_864x480_uncertainty.pt',)

# %%
# !unzip "./mot16.zip" -d "/content"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/MOT16/train/MOT16-02/img1/000361.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000362.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000363.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000364.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000365.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000366.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000367.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000368.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000369.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000370.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000371.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000372.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000373.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000374.jpg
#   inflating: /content/MOT16/train/MOT16-02/img1/000375.jpg
# ...

# %%
# !python /content/Towards-Realtime-MOT/track.py --cfg /content/Towards-Realtime-MOT/cfg/yolov3_1088x608.cfg --weights /content/jde_1088x608_uncertainty.pt --test-mot16 --save-images --save-videos
# Out:
# Namespace(cfg='/content/Towards-Realtime-MOT/cfg/yolov3_1088x608.cfg', conf_thres=0.5, iou_thres=0.5, min_box_area=200, nms_thres=0.4, save_images=True, save_videos=True, test_mot16=True, track_buffer=30, weights='/content/jde_1088x608_uncertainty.pt')
#
# 2020-05-24 13:39:20 [INFO]: start seq: MOT16-01
# 2020-05-24 13:39:30 [INFO]: Processing frame 0 (100000.00 fps)
# /content/Towards-Realtime-MOT/tracker/multitracker.py:142: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "tlbr_to_tlwh" failed type inference due to: non-precise type pyobject
# [1] During: typing of argument at /content/Towards-Realtime-MOT/tracker/multitracker.py (145)
#
# File "Towards-Realtime-MOT/tracker/multitracker.py", line 145:
#     def tlbr_to_tlwh(tlbr):
#         ret = np.asarray(tlbr).copy()
#         ^
#
#   @staticmethod
# ...

# %%
# !mv ./MOT16/outputs/content ./Towards-Realtime-MOT/images_1088x608

# %%
# !mv ./MOT16/results/content ./Towards-Realtime-MOT/annotations_1088x608

# %%
# !rm -rf ./MOT16/outputs
# !rm -rf ./MOT16/results

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r "./Towards-Realtime-MOT/annotations_1088x608" "./drive/My Drive/MOT_Dataset_Weights"

# %%
# !cp -r "./Towards-Realtime-MOT/images_1088x608" "./drive/My Drive/MOT_Dataset_Weights"
